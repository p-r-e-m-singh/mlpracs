# %% [markdown]
# Implement  Linear regression to predict house prices based on multiple variables using regularization techniques and explain how regularisation overcome overfitting problem. (use inbuilt dataset boston-  from sklearn.datasets import load_boston)

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
# Step 1: Load and preprocess the data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train / 255.0  # Normalize the pixel values between 0 and 1
X_test = X_test / 255.0
y_train = to_categorical(y_train)  # One-hot encode the target variable
y_test = to_categorical(y_test)

# Step 2: Define the neural network architecture
model = Sequential([
    Flatten(input_shape=(28, 28)),  # Flatten the input image (28x28 pixels) into a 1D array
    Dense(128, activation='relu'),  # Hidden layer with 128 neurons and ReLU activation
    Dense(10, activation='softmax')  # Output layer with 10 neurons (one for each digit) and softmax activation
])

# Step 3: Compile the model
model.compile(optimizer='adam',  # Adam optimizer
              loss='categorical_crossentropy',  # Categorical cross-entropy loss function
              metrics=['accuracy'])

# Step 4: Train the model
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_split=0.2)

# Step 5: Evaluate the model
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)

# Step 6: Plot training history (optional)
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/10
# 1500/1500 [==============================] - 6s 3ms/step - loss: 0.2929 - accuracy: 0.9168 - val_loss: 0.1565 - val_accuracy: 0.9580
# Epoch 2/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.1324 - accuracy: 0.9607 - val_loss: 0.1240 - val_accuracy: 0.9638
# Epoch 3/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0903 - accuracy: 0.9732 - val_loss: 0.1012 - val_accuracy: 0.9699
# Epoch 4/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0679 - accuracy: 0.9803 - val_loss: 0.0911 - val_accuracy: 0.9737
# Epoch 5/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0521 - accuracy: 0.9843 - val_loss: 0.0891 - val_accuracy: 0.9739
# Epoch 6/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0402 - accuracy: 0.9882 - val_loss: 0.0919 - val_accuracy: 0.9728
# Epoch 7/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 0.0911 - val_accuracy: 0.9753
# Epoch 8/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0260 - accuracy: 0.9923 - val_loss: 0.0894 - val_accuracy: 0.9753
# Epoch 9/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0207 - accuracy: 0.9940 - val_loss: 0.0960 - val_accuracy: 0.9749
# Epoch 10/10
# 1500/1500 [==============================] - 6s 4ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 0.0952 - val_accuracy: 0.9728
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0887 - accuracy: 0.9739
# Test accuracy: 0.9739000201225281
